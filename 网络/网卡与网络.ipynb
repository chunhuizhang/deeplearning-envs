# %%
from IPython.display import Image

# %% [markdown]
# - 注意 google.com 与 google.com.hk 是不同的域名
# - 下载（上传）网速，局域网网速，
#     - https://www.bilibili.com/video/BV1xrZmYYEYj/
#     - 下载（上传）网速：联通万兆带宽；
#         - 上传是下载的1/8??
#     - 网卡
#         - 二手400GbE网卡；
#         - 地表最快网卡：英伟达（迈络思）；

# %% [markdown]
# ## 家庭组网

# %%
Image('./imgs/home-network.png', width=400)

# %% [markdown]
# ### 光猫

# %% [markdown]
# - 白细线：光纤线，连光猫，
#     - 当然现在光猫，也支持路由器功能（创建局域网）

# %% [markdown]
# ### 路由器

# %% [markdown]
# - 设置地址：`http://192.168.1.1/`
#     - 有的是 `http://192.168.0.1/`
# - wan口，wlan口

# %% [markdown]
# ## IP

# %% [markdown]
# - ubuntu 命令
#     - `traceroute baidu.com`：查看 ip 路由；

# %% [markdown]
# ### dhcp

# %% [markdown]
# - ip地址如何获取
#     - 手动设置：ip地址，子网掩码，默认网关；
# - 通过 dhcp 协议
#     - （动态）获取 ip 地址
#     - 保证不冲突
# - 家庭组网
#     - 家庭中的 dhcp 服务器就是路由器；

# %% [markdown]
# ### 以太网与wlan

# %% [markdown]
# - 以太网：Ethernet
#     - eth1/eth2：传统的以太网编号；
#     - eno1/eno2：以太网的新编号；

# %% [markdown]
# ## DNS

# %% [markdown]
# - 阿里DNS
#     - 233.5.5.5
#     - 233.6.6.6

# %% [markdown]
# ## 服务器端常见的 3 种网卡

# %% [markdown]
# - IB：Infinite Band

# %% [markdown]
# ## bascis

# %% [markdown]
# - `ping`
#     - ping github.com, if ping failed. it is DNS error.
# - `dns`
# - 端口号占用
#     - `netstat -anp | grep 29500`
#     - `lsof -i :29500`

# %% [markdown]
# ## 监听ip与端口号

# %% [markdown]
# - 除了把 jupyter notebook 的后台服务启起来，每启动一个具体的 notebook，都会占用一个 port（以及会启动一个 pid）；

# %% [markdown]
# ```
# $ netstat -tulpn
# # listen 表示监听，最后一列为 PIP/Program name
# $ netstat -tulpn | grep LISTEN
# ```

# %% [markdown]
# ## 端口转发（forward）
