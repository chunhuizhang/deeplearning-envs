# %%
from IPython.display import Image

# %% [markdown]
# ## basics

# %% [markdown]
# - 概念
#     - FMA：fused multiply and add；

# %% [markdown]
# ## gpu cards

# %%
Image('./imgs/a800-h800.png', width=500)

# %% [markdown]
# ## tensor core

# %% [markdown]
# - 矩阵乘法优化
# - 还包括 sparse tensor code
#     - 稀疏矩阵处理
