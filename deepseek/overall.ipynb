# %% [markdown]
# - https://github.com/sgl-project/sglang/blob/main/benchmark/deepseek_v3/README.md
#     - https://docs.skypilot.co/en/latest/examples/models/deepseek-r1.html
# - h100 支持 fp8, a100 不支持 fp8，支持 bf16
